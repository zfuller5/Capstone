# %% [markdown]
# ## Imports
# ---

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression, Ridge, RidgeCV, Lasso, LassoCV
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
from sklearn.preprocessing import StandardScaler, PolynomialFeatures

# %% [markdown]
# ## Read in all positional data versus Defense
# ---

# %%
# read position versus defense data
QB_def = pd.read_csv('../data/DEF_QB.csv', index_col=[0])
RB_def = pd.read_csv('../data/DEF_RB.csv', index_col=[0])
WR_def = pd.read_csv('../data/DEF_WR.csv', index_col=[0])
TE_def = pd.read_csv('../data/DEF_TE.csv', index_col=[0])

# %%
# look at season long QB statistics against Defenses
sns.pairplot(QB_def);

# %%
# look at season long RB statistics against Defenses
sns.pairplot(RB_def);

# %%
# look at season long TE statistics against Defenses
sns.pairplot(TE_def);

# %%
# look at season long WR statistics against Defenses
sns.pairplot(WR_def);

# %% [markdown]
# ---
# ## The majority of the scatter plots show linear relationships, therefore linear models will be highlighted in addition to KNN and Decision Trees.
# ---
